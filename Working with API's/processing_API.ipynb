# %% [markdown]
# # Processing an API Response

# %%
import requests

# %%
# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Store API's response in a variable.
response_dict = r.json()

# Process results.
print(response_dict.keys())
# Out:
# Status code: 200
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %% [markdown]
# # Working with the Response Directory

# %%
print(f"Total repositories: {response_dict['total_count']}")

# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

# Examine the first repository.
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Total repositories: 4445376
# Repositories returned: 30
#
# Keys: 74
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# trees_url
# updated_at
# url
# watchers
# watchers_count

# %%
# Lets pull out the values for some of the keys in repo_dict:
print("\nSelected information about first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")
# Out:
# Selected information about first repository:
# Name: system-design-primer
# Owner: donnemartin
# Stars: 76136
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2019-11-11T06:01:29Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.

# %% [markdown]
# # Summarizing the Top Repositories

# %%
print(f"Total repositories: {response_dict['total_count']}")

# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")
      
# >>
print("\nSelected information about each repository:")
for repo_dict in repo_dicts:
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
    print(f"Description: {repo_dict['description']}")
# <<
# Out:
# Total repositories: 4445376
# Repositories returned: 30
#
# Selected information about each repository:
# Name: system-design-primer
# Owner: donnemartin
# Stars: 76136
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2019-11-11T06:01:29Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
# Name: awesome-python
# Owner: vinta
# Stars: 75340
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2019-11-11T05:57:39Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources
# Name: public-apis
# Owner: public-apis
# Stars: 64753
# Repository: https://github.com/public-apis/public-apis
# Created: 2016-03-20T23:49:42Z
# Updated: 2019-11-11T05:24:30Z
# Description: A collective list of free APIs for use in software and web development.
# Name: models
# Owner: tensorflow
# Stars: 59174
# Repository: https://github.com/tensorflow/models
# Created: 2016-02-05T01:15:20Z
# Updated: 2019-11-11T05:10:26Z
# Description: Models and examples built with TensorFlow
# Name: youtube-dl
# Owner: ytdl-org
# Stars: 57593
# Repository: https://github.com/ytdl-org/youtube-dl
# Created: 2010-10-31T14:35:07Z
# Updated: 2019-11-11T05:49:34Z
# Description: Command-line program to download videos from YouTube.com and other video sites
# Name: thefuck
# Owner: nvbn
# Stars: 50243
# Repository: https://github.com/nvbn/thefuck
# Created: 2015-04-08T15:08:04Z
# Updated: 2019-11-11T06:07:38Z
# Description: Magnificent app which corrects your previous console command.
# Name: flask
# Owner: pallets
# Stars: 47452
# Repository: https://github.com/pallets/flask
# Created: 2010-04-06T11:11:59Z
# Updated: 2019-11-11T03:39:02Z
# Description: The Python micro framework for building web applications.
# Name: keras
# Owner: keras-team
# Stars: 45288
# Repository: https://github.com/keras-team/keras
# Created: 2015-03-28T00:35:42Z
# Updated: 2019-11-11T05:54:58Z
# Description: Deep Learning for humans
# Name: django
# Owner: django
# Stars: 45151
# Repository: https://github.com/django/django
# Created: 2012-04-28T02:47:18Z
# Updated: 2019-11-11T05:56:53Z
# Description: The Web framework for perfectionists with deadlines.
# Name: httpie
# Owner: jakubroztocil
# Stars: 43717
# Repository: https://github.com/jakubroztocil/httpie
# Created: 2012-02-25T12:39:13Z
# Updated: 2019-11-11T05:51:30Z
# Description: As easy as HTTPie /aitch-tee-tee-pie/ 🥧 Modern command line HTTP client – user-friendly curl alternative with intuitive UI, JSON support, syntax highlighting, wget-like downloads, extensions, etc.  https://twitter.com/clihttp
# Name: awesome-machine-learning
# Owner: josephmisiti
# Stars: 42495
# Repository: https://github.com/josephmisiti/awesome-machine-learning
# Created: 2014-07-15T19:11:19Z
# Updated: 2019-11-11T04:33:26Z
# Description: A curated list of awesome Machine Learning frameworks, libraries and software.
# Name: requests
# Owner: psf
# Stars: 40740
# Repository: https://github.com/psf/requests
# Created: 2011-02-13T18:38:17Z
# Updated: 2019-11-11T00:38:03Z
# Description: A simple, yet elegant HTTP library.
# Name: ansible
# Owner: ansible
# Stars: 40272
# Repository: https://github.com/ansible/ansible
# Created: 2012-03-06T14:58:02Z
# Updated: 2019-11-11T05:31:01Z
# Description: Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy. Avoid writing scripts or custom code to deploy and update your applications — automate in a language that approaches plain English, using SSH, with no agents to install on remote systems. https://docs.ansible.com/ansible/
# Name: scikit-learn
# Owner: scikit-learn
# Stars: 37911
# Repository: https://github.com/scikit-learn/scikit-learn
# Created: 2010-08-17T09:43:38Z
# Updated: 2019-11-11T05:38:40Z
# Description: scikit-learn: machine learning in Python
# Name: scrapy
# Owner: scrapy
# Stars: 35033
# Repository: https://github.com/scrapy/scrapy
# Created: 2010-02-22T02:01:14Z
# Updated: 2019-11-11T05:49:42Z
# Description: Scrapy, a fast high-level web crawling & scraping framework for Python.
# Name: big-list-of-naughty-strings
# Owner: minimaxir
# Stars: 33505
# Repository: https://github.com/minimaxir/big-list-of-naughty-strings
# Created: 2015-08-08T20:57:20Z
# Updated: 2019-11-10T20:01:35Z
# Description: The Big List of Naughty Strings is a list of strings which have a high probability of causing issues when used as user-input data.
# Name: shadowsocks
# Owner: shadowsocks
# Stars: 31815
# Repository: https://github.com/shadowsocks/shadowsocks
# Created: 2012-04-20T13:10:49Z
# Updated: 2019-11-11T03:53:24Z
# Description: None
# Name: face_recognition
# Owner: ageitgey
# Stars: 29624
# Repository: https://github.com/ageitgey/face_recognition
# Created: 2017-03-03T21:52:39Z
# Updated: 2019-11-11T03:47:46Z
# Description: The world's simplest facial recognition api for Python and the command line
# Name: XX-Net
# Owner: XX-net
# Stars: 29071
# Repository: https://github.com/XX-net/XX-Net
# Created: 2015-01-15T09:35:51Z
# Updated: 2019-11-11T05:56:10Z
# Description: a web proxy tool
# Name: home-assistant
# Owner: home-assistant
# Stars: 28307
# Repository: https://github.com/home-assistant/home-assistant
# Created: 2013-09-17T07:29:48Z
# Updated: 2019-11-11T05:50:10Z
# Description: :house_with_garden: Open source home automation that puts local control and privacy first
# Name: you-get
# Owner: soimort
# Stars: 27927
# Repository: https://github.com/soimort/you-get
# Created: 2012-08-20T15:53:36Z
# Updated: 2019-11-11T05:54:21Z
# Description: :arrow_double_down: Dumb downloader that scrapes the web
# Name: cpython
# Owner: python
# Stars: 27656
# Repository: https://github.com/python/cpython
# Created: 2017-02-10T19:23:51Z
# Updated: 2019-11-11T04:12:26Z
# Description: The Python programming language
# Name: faceswap
# Owner: deepfakes
# Stars: 27297
# Repository: https://github.com/deepfakes/faceswap
# Created: 2017-12-19T09:44:13Z
# Updated: 2019-11-11T05:03:34Z
# Description: Deepfakes Software For All
# Name: 100-Days-Of-ML-Code
# Owner: Avik-Jain
# Stars: 27003
# Repository: https://github.com/Avik-Jain/100-Days-Of-ML-Code
# Created: 2018-07-05T09:11:43Z
# Updated: 2019-11-11T03:40:10Z
# Description: 100 Days of ML Coding
# Name: certbot
# Owner: certbot
# Stars: 25878
# Repository: https://github.com/certbot/certbot
# Created: 2014-11-12T02:52:20Z
# Updated: 2019-11-10T14:19:09Z
# Description: Certbot is EFF's tool to obtain certs from Let's Encrypt and (optionally) auto-enable HTTPS on your server.  It can also act as a client for any other CA that uses the ACME protocol.
# Name: CppCoreGuidelines
# Owner: isocpp
# Stars: 25019
# Repository: https://github.com/isocpp/CppCoreGuidelines
# Created: 2015-08-19T20:22:52Z
# Updated: 2019-11-11T04:03:49Z
# Description: The C++ Core Guidelines are a set of tried-and-true guidelines, rules, and best practices about coding in C++
# Name: Deep-Learning-Papers-Reading-Roadmap
# Owner: floodsung
# Stars: 24463
# Repository: https://github.com/floodsung/Deep-Learning-Papers-Reading-Roadmap
# Created: 2016-10-14T11:49:48Z
# Updated: 2019-11-11T05:52:46Z
# Description: Deep Learning papers reading roadmap for anyone who are eager to learn this amazing tech!
# Name: tldr
# Owner: tldr-pages
# Stars: 24123
# Repository: https://github.com/tldr-pages/tldr
# Created: 2013-12-08T07:34:43Z
# Updated: 2019-11-11T05:35:00Z
# Description: :books: Simplified and community-driven man pages
# Name: sentry
# Owner: getsentry
# Stars: 22714
# Repository: https://github.com/getsentry/sentry
# Created: 2010-08-30T22:06:41Z
# Updated: 2019-11-11T02:56:23Z
# Description: Sentry is cross-platform application monitoring, with a focus on error reporting.
# Name: python-patterns
# Owner: faif
# Stars: 22701
# Repository: https://github.com/faif/python-patterns
# Created: 2012-06-06T21:02:35Z
# Updated: 2019-11-11T05:03:32Z
# Description: A collection of design patterns/idioms in Python

# %% [markdown]
# # Visualizing Repositories Using Plotly

# %%
import requests
from plotly.graph_objs import Bar
from plotly import offline

# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process Results.
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names, stars = [], []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

# Make visualization.
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars,
}]

my_layout = {
    'title': 'Most-Starred Python Projects on GitHub',
    'xaxis': {'title': 'Repository'},
    'yaxis': {'title': 'Stars'}
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# Status code: 200
# 'python_repos.html'

# %% [markdown]
# # Refining Plotly Charts

# %%
import requests
from plotly.graph_objs import Bar
from plotly import offline

# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process Results.
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names, stars = [], []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

# Make visualization.
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars,
    # >>
    'marker': {
        'color': 'rgb(60, 100, 150)',
        'line': {'width': 1.5, 'color': 'rgb(25, 25, 25)'}
    },
    'opacity': 0.6,
    # <<
}]

my_layout = {
    'title': 'Most-Starred Python Projects on GitHub',
    # >>
    'titlefont': {'size': 28},
    'xaxis': {
        'title': 'Repository',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
    'yaxis': {
        'title': 'Stars',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos_w_more_style.html')
# Out:
# Status code: 200
# 'python_repos_w_more_style.html'

# %% [markdown]
# # Adding Custom Tooltips

# %%
import requests
from plotly.graph_objs import Bar
from plotly import offline

# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process Results.
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names, stars, labels = [], [], []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner}<br />{description}"
    labels.append(label)

# Make visualization.
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars,
    # >>
    'hovertext': labels,
    # <<
    'marker': {
        'color': 'rgb(60, 100, 150)',
        'line': {'width': 1.5, 'color': 'rgb(25, 25, 25)'}
    },
    'opacity': 0.6,
}]

my_layout = {
    'title': 'Most-Starred Python Projects on GitHub',
    # >>
    'titlefont': {'size': 28},
    'xaxis': {
        'title': 'Repository',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
    'yaxis': {
        'title': 'Stars',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos_w_hovertxt.html')
# Out:
# Status code: 200
# 'python_repos_w_hovertxt.html'

# %% [markdown]
# # Adding Clickable links to Our Graphs

# %%
import requests
from plotly.graph_objs import Bar
from plotly import offline

# Make an API call and store the response.
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process Results.
response_dict = r.json()
repo_dicts = response_dict['items']

# >>

repo_links, stars, labels = [], [], []
for repo_dict in repo_dicts:
    repo_name = repo_dict['name']
    repo_url = repo_dict['html_url']
    repo_link = f" <a href='{repo_url}'>{repo_name}</a>"
    repo_links.append(repo_link)
    stars.append(repo_dict['stargazers_count'])
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner}<br />{description}"
    labels.append(label)

# Make visualization.
data = [{
    'type': 'bar',
    'x': repo_links,
    'y': stars,
    # >>
    'hovertext': labels,
    # <<
    'marker': {
        'color': 'rgb(60, 100, 150)',
        'line': {'width': 1.5, 'color': 'rgb(25, 25, 25)'}
    },
    'opacity': 0.6,
}]

my_layout = {
    'title': 'Most-Starred Python Projects on GitHub',
    # >>
    'titlefont': {'size': 28},
    'xaxis': {
        'title': 'Repository',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
    'yaxis': {
        'title': 'Stars',
        'titlefont': {'size': 24},
        'tickfont': {'size': 14},
    },
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos_w_hovertxt&links.html')
# Out:
# Status code: 200
# 'python_repos_w_hovertxt&links.html'
